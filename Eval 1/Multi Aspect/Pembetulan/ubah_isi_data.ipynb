# %%
import pandas as pd

df = pd.read_csv("data_with_true_label.csv", delimiter=";")

df.loc[
    (df['commenter_username'] == 'engineeringprosesbisnis') &
    (df['comment_text'] == 'Mantab:clapping_hands::clapping_hands::clapping_hands:'),
    ['true_aspect_1', 'true_aspect_2']
] = 'Lainnya'

df.loc[
    (df['commenter_username'] == 'bayuhadileksana') &
    (df['comment_text'] == 'Mantap'),
    ['true_aspect_1', 'true_aspect_2']
] = 'Lainnya'

df.loc[
    (df['commenter_username'] == 'jibobsaputro18') &
    (df['comment_text'] == 'Kalau pengerjaan ganti stop kran telah selesai terlebih dahulu, baru langsung pembayaran apa bisa?'),
    ['true_aspect_1']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['true_aspect_2'] == 'air Kotor/Bau'),
    ['true_aspect_2']
] = 'Air Kotor/Bau'

df.loc[
    (df['true_aspect_2'] == 'Pelayanann'),
    ['true_aspect_2']
] = 'Pelayanan'




df.loc[
    (df['commenter_username'] == 'esuhar1') &
    (df['comment_text'] == 'Air PDAM daerah Jemurwonosari pagi sdh mati sore juga kalau pun keluar kecil , juga kotor tolong d cek'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'harry_loe') &
    (df['comment_text'] == 'ngajuin surat keberatan tagihan dari bulan januari sampe sekarang gak ada tanggapan. tagihan naik gara2 meter pdam yg rusak, malah pelanggan yang harus bayar kelebihan tagihannya. sekelas perusahaan daerah koq gak profesional gini'),
    ['true_aspect_2']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'jefrisusilo') &
    (df['comment_text'] == 'Laporan ke PDAM tambah dikasih nomer pencatat meter...ditelp gaknisanwoi. Piye Iki tagihan ku gak sesuai meteran ....fast respon dong'),
    ['true_aspect_2']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'diahpalupi1') &
    (df['comment_text'] == 'Cra hubungi gmna ya biar ada kejelasan.. sya sudah byar biaya penggantian stop kran. Ktanya nunggu 1-7hari tp smpai hari ke 7 blm ada petugas dtang.. tlong  pencerahan nya min:folded_hands:'),
    ['true_aspect_2']
] = 'Pemasangan'

df.loc[
    (df['commenter_username'] == 'mc_rinov') &
    (df['comment_text'] == 'gmn pemberitahuan resminya kalo memang peraturan kost 6 kamar dikenakan tarif 3.2A ? apa akal²an petugas aja, dikira kalo punya kost penghasilan banyak gitu?trs diganti dari 2.1 ake 3.2A ?ini cuma 6 kamar, bukan 10 atau 20 kamar,'),
    ['true_aspect_2']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'fairuzyqonitah') &
    (df['comment_text'] == 'Saya sudah mengajukan penggantian meteran, karena meteran rumah yg saya tinggali macet/rusak, sejak tanggal 23 Januari 2025 dan sampai sekarang belum ada tindak lanjut. Dengan no pengaduan PM2025000000825. LALU TAGIHAN SAYA BULAN JANUARI METERAN AKHIR 136 TAPI DI TAGIHAN BULAN FEBRUARI METERAN AWAL 116 DAN METERAN AKHIR 136. PADAHAL SAYA SUDAH LAPOR METERAN SAYA MACET/RUSAK, TAPI MALAH CATATAN METERAN YG DIUBAH-UBAH'),
    ['true_aspect_1']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == '_iniditaputrii') &
    (df['comment_text'] == 'Min mau pengaduan gimana gak ada respon @pdamsuryasembada tagihan bln ini kok tbtb membengkak pdhal bertahun tahun gk pernah air sampai habis ratusan ribu'),
    ['true_aspect_2']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'anisulianifarhan') &
    (df['comment_text'] == 'Apakah pengantian meteran pdam masih gratis atau berbayar ?'),
    ['true_aspect_2']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == 'harry_loe') &
    (df['comment_text'] == 'Saya mengajukan surat keberatan tagihan dari bulan januari 2025, krn meter PDAM rusak. Sampai sekarang tidak ada tanggapan. meter pdam yg rusak, masa pelanggan yang harus bayar tagihannya?padahal air yang digunakan tidak sebanyak tagihannya.'),
    ['comment_text']
] = 'Saya mengajukan surat keberatan tagihan dari bulan januari 2025, meter PDAM rusak. Sampai sekarang tidak ada tanggapan. meter pdam yg rusak, tapi pelanggan yang harus bayar tagihannya?padahal air yang digunakan tidak sebanyak tagihannya.'

df.loc[
    (df['commenter_username'] == 'asma_subiantoro') &
    (df['comment_text'] == 'Diganti meteran baru tagihan malah lbh banyak :person_facepalming:'),
    ['comment_text']
] = 'Diganti meteran baru tapi tagihan malah lbh banyak :person_facepalming:'

df.loc[
    (df['commenter_username'] == 'aini_al_aydrus') &
    (df['comment_text'] == 'Air mati seharian hidup malam ajja padahal kota besar air mati terus pembayaran naik 100%'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'mr_yoel_setiawan') &
    (df['comment_text'] == 'Untuk penggantian Meter diminta bayar vja Indomart, stlah bayar via Indomart katae H+1 br msk, stlah H+1 msk br di Jadwalkan kunjungan....LUAMA, Air sudah bocor deras yg nanggu pemilik rumah. Knp lama skali prosesnya?'),
    ['comment_text']
] = 'Untuk penggantian Meter diminta bayar vja Indomart, stlah bayar via Indomart katae H+1 br msk, stlah H+1 msk br di Jadwalkan kunjungan. LUAMA, Air sudah bocor deras yg nanggu pemilik rumah. Knp lama skali prosesnya?'

df.loc[
    (df['commenter_username'] == 'mr_yoel_setiawan') &
    (df['comment_text'] == 'Untuk penggantian Meter diminta bayar vja Indomart, stlah bayar via Indomart katae H+1 br msk, stlah H+1 msk br di Jadwalkan kunjungan. LUAMA, Air sudah bocor deras yg nanggu pemilik rumah. Knp lama skali prosesnya?'),
    ['true_aspect_2']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == 'aryadiahshianti') &
    (df['comment_text'] == 'halo @pdamsuryasembada  sy ada wa tp slow respon ya, nomor call centernya jg, operatornya sibuk terus, air ditempat saya mati dari semalam, apa ada solusi untuk pengaduan saya'),
    ['comment_text']
] = 'halo @pdamsuryasembada  sy ada wa tp slow respon ya, nomor call centernya jg, operatornya sibuk terus, sedangkan air ditempat saya mati dari semalam, apa ada solusi untuk pengaduan saya'

df.loc[
    (df['commenter_username'] == 'aryadiahshianti') &
    (df['comment_text'] == 'halo @pdamsuryasembada  sy ada wa tp slow respon ya, nomor call centernya jg, operatornya sibuk terus, sedangkan air ditempat saya mati dari semalam, apa ada solusi untuk pengaduan saya'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'aryadiahshianti') &
    (df['comment_text'] == 'halo @pdamsuryasembada  sy ada wa tp slow respon ya, nomor call centernya jg, operatornya sibuk terus, sedangkan air ditempat saya mati dari semalam, apa ada solusi untuk pengaduan saya'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'mc_rinov') &
    (df['comment_text'] == 'gmn pemberitahuan resminya kalo memang peraturan kost 6 kamar dikenakan tarif 3.2A ? apa akal²an petugas aja, dikira kalo punya kost penghasilan banyak gitu?trs diganti dari 2.1 ke 3.2A ?ini cuma 6 kamar, bukan 10 atau 20 kamar,'),
    ['true_aspect_2']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'nazua_99') &
    (df['comment_text'] == 'Kenapa laporan by WhatsApp PDAM  GK ada jawaban ya kak, padahal saya sudah daftar mau tanya soal kekurangan persyaratan pasang baru'),
    ['true_aspect_2']
] = 'Pemasangan'

df.loc[
    (df['commenter_username'] == 'nazua_99') &
    (df['comment_text'] == 'Kenapa laporan by WhatsApp PDAM  GK ada jawaban ya kak, padahal saya sudah daftar mau tanya soal kekurangan persyaratan pasang baru'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'afi.ummunufail08') &
    (df['comment_text'] == 'Min kalau ngontrak rumah belum dipasang pdam caranya gimana?karena rumah yang dikontrak warisan'),
    ['true_aspect_1']
] = 'Pemasangan'

df.loc[
    (df['commenter_username'] == 'ynn_joyo') &
    (df['comment_text'] == 'Saya dari agustus 2024 sampai sekarang blm ada tanggapan pasang baru padahal :loudly_crying_face: wes ganti tahun min :loudly_crying_face:'),
    ['true_aspect_2']
] = 'Pemasangan'

df.loc[
    (df['commenter_username'] == 'banjoz_aris') &
    (df['comment_text'] == 'Saya belum di survey" Minn sdh pengajuan lama'),
    ['comment_text']
] = 'Saya belum di survey" Min, padahal sdh pengajuan lama'

df.loc[
    (df['commenter_username'] == 'banjoz_aris') &
    (df['comment_text'] == 'Saya belum di survey" Min, padahal sdh pengajuan lama'),
    ['true_aspect_2']
] = 'Pemasangan'

df.loc[
    (df['commenter_username'] == 'banjoz_aris') &
    (df['comment_text'] == 'Saya belum di survey" Min, padahal sdh pengajuan lama'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'dilla_iyyakamu') &
    (df['comment_text'] == 'Air PDAM SBY pusat punyakku keruh  kyk air sumur.. Bayarnya larang tp airnya keruh bauk'),
    ['comment_text']
] = 'Air PDAM SBY pusat punyakku keruh  kyk air sumur. Padahal bayarnya larang tp airnya keruh bauk'

df.loc[
    (df['commenter_username'] == '54111_uge7') &
    (df['comment_text'] == 'Kualitas airnya perlu dicek dan dikontrol...jangan cuman datang cek meteran saja....dan jangan cari untung saja gede perhatikan kemampuan konsumennya,....'),
    ['true_aspect_2']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'ali_murtadlo78') &
    (df['comment_text'] == 'Min, sy pengaduan ganti meteran hingga 14 hari kerja kok blm ada tanggapan'),
    ['comment_text']
] = 'Min, sy pengaduan ganti meteran hingga 14 hari kerja tapi blm ada tanggapan'

df.loc[
    (df['commenter_username'] == 'kiemfon') &
    (df['comment_text'] == 'Siang @pdamsuryasembada sy tinggal di bulak rukem timur, air di daerah sy debitnya kecil cenderung tdk keluar, sy sdh pernah lapor bebetapa kali & sdh di datangi, tp tetap saja tdk lancar, pernah sy tny kenapa, ktnya ada galian, minggu yg lalu memang ada keluar 1 hr saja selanjunya mengecil lagi & airnya sangat keruh'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'yesy_atmaja') &
    (df['comment_text'] == 'min, sambikerep mati airnya kok gk ada pemberitahuan. pagi2 pula wktunya masak,sekolah,kerja :disappointed_face:'),
    ['comment_text']
] = 'Min, sambikerep mati airnya tapi gk ada pemberitahuan. pagi2 pula wktunya masak,sekolah,kerja :disappointed_face:'

df.loc[
    (df['commenter_username'] == 'auliwahyufebianti') &
    (df['comment_text'] == 'Tlfon cs ga bisa, wa cs ga ada respon... Sampai skrg air blm keluarrrrrrrrr'),
    ['comment_text']
] = 'Tlfon cs ga bisa, wa cs ga ada respon. tapi sampai skrg air blm keluarrrrrrrrr'

df.loc[
    (df['commenter_username'] == 'auliwahyufebianti') &
    (df['comment_text'] == 'Tlfon cs ga bisa, wa cs ga ada respon. tapi sampai skrg air blm keluarrrrrrrrr'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'auliwahyufebianti') &
    (df['comment_text'] == 'Tlfon cs ga bisa, wa cs ga ada respon. tapi sampai skrg air blm keluarrrrrrrrr'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'salmasalma_25') &
    (df['comment_text'] == 'Didepan rumah ada kebocoran pipa,sampai airnya keluar terus,sudah dilaporkan diiyain aja,,terus laporan lagi Sama orang yang biasanya ngecek meteran dari rumah ke rumah,tetap aja TDK ada tindakan udah hari ketiga setelah difoto sama orang PDAMnya sendiri tapi belum ada tindakan'),
    ['comment_text']
] = 'Didepan rumah ada kebocoran pipa,sampai airnya keluar terus,sudah dilaporkan diiyain aja,,terus laporan lagi Sama orang yang biasanya ngecek meteran dari rumah ke rumah,tetapi aja TDK ada tindakan udah hari ketiga setelah difoto sama orang PDAMnya sendiri tapi belum ada tindakan'

df.loc[
    (df['commenter_username'] == 'shadrinarizkyamel') &
    (df['comment_text'] == 'Min area kodam air nya kok mati?  Tidak ada info pemberitahuan'),
    ['comment_text']
] = 'Min area kodam air nya kok mati? tetapi Tidak ada info pemberitahuan'

df.loc[
    (df['commenter_username'] == 'kiki_keket') &
    (df['comment_text'] == 'Pak air di pulosari mati, kok tidak ada pemberitahuan ya?'),
    ['comment_text']
] = 'Pak air di pulosari mati, tapi tidak ada pemberitahuan ya?'

df.loc[
    (df['commenter_username'] == 'bobiharto') &
    (df['comment_text'] == 'So far bad experience, air mati sebelum masuk meteran tetapi tidak ada penanganan yang baik dari pihak PDAM, pelaporan hanya cmn bertugas melapor tanpa ada konfirmasi pengerjaan yg jelas, laporan setelah tinjau pun tidak akurat, kacau'),
    ['comment_text']
] = 'air mati sebelum masuk meteran tetapi tidak ada tindakan yang baik dari pihak PDAM, pelaporan hanya cmn bertugas melapor tanpa ada konfirmasi pengerjaan yg jelas, laporan setelah tinjau pun tidak akurat, kacau'

df.loc[
    (df['commenter_username'] == 'yani_wulandari14') &
    (df['comment_text'] == 'Pdam mati jm 3 kok ga ada pemberitahuan:woman_facepalming::woman_facepalming:'),
    ['comment_text']
] = 'Pdam mati jam 3 tapi tidak ada pemberitahuan:woman_facepalming::woman_facepalming:'

df.loc[
    (df['commenter_username'] == 'ulfadwiwijaya') &
    (df['comment_text'] == '@pdamsuryasembada nyalain airnya min , air mati tanpa pemberitahuan, menghambat aktifitas pagi aja :crying_face:'),
    ['comment_text']
] = '@pdamsuryasembada nyalain airnya min , air mati tapi tanpa pemberitahuan, menghambat aktifitas pagi aja :crying_face:'

df.loc[
    (df['commenter_username'] == 'antoniusadji') &
    (df['comment_text'] == 'PDAM Kebraon kumat maneh iki lhoo. Gatau nggawe pengumuman blasss. Heran'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'puriniken') &
    (df['comment_text'] == 'Maaf pak di tempat kami daerah Surabaya barat airnya kotor nyalanya jugaa gak deras mana bayarnya mahal .. kalau bisa di turunkan tarif air PDAM'),
    ['comment_text']
] = 'Maaf pak di tempat kami daerah Surabaya barat airnya kotor nyalanya jugaa gak deras tapi bayarnya mahal. kalau bisa di turunkan tarif air PDAM'

df.loc[
    (df['commenter_username'] == 'haris.erlangga') &
    (df['comment_text'] == 'Murah tapi butek kotor'),
    ['true_aspect_1']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'haris.erlangga') &
    (df['comment_text'] == 'Murah tapi butek kotor'),
    ['true_aspect_2']
] = 'Air Kotor/Bau'

df.loc[
    (df['commenter_username'] == 'greenhouse_my_darling') &
    (df['comment_text'] == 'Air PDAM murah tapi butek,percuma cak'),
    ['true_aspect_1']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'greenhouse_my_darling') &
    (df['comment_text'] == 'Air PDAM murah tapi butek,percuma cak'),
    ['true_aspect_2']
] = 'Air Kotor/Bau'

df.loc[
    (df['commenter_username'] == 'halohi7002') &
    (df['comment_text'] == 'Halo kak, kebraon sek suwe ta murupe? Gaonok info blas moro2 mati rek'),
    ['comment_text']
] = 'Halo kak, kebraon sek suwe ta murupe? Sedangkan gaonok info blas moro2 mati rek'

df.loc[
    (df['commenter_username'] == 'indra_wahyudi_suroboyo') &
    (df['comment_text'] == 'Sebaiknya kalau ada giat pekerjaan mematikan aliran Air PDAM kepada Warga. Beberapa hari sebelumnya ada pemberitahuan agar warga dapat mempersiapkan dampaknya. Kebraon mati dari tadi jam 7.30 sampai pukul 13.10 juga belum mengalir. PDAM bisa lebih profesional dalam pelayanan kepada masyarakat. Bukan hanya maaf saja. Agar tidak menjadi Budaya pelayanan apa adanya :fire::fire:'),
    ['comment_text']
] = 'Sebaiknya kalau ada giat pekerjaan mematikan aliran Air PDAM kepada Warga. Beberapa hari sebelumnya ada pemberitahuan agar warga dapat mempersiapkan dampaknya. Kebraon mati dari tadi jam 7.30 sampai pukul 13.10 juga belum mengalir.Padahal PDAM bisa lebih profesional dalam pelayanan kepada masyarakat. Bukan hanya maaf saja. Agar tidak menjadi Budaya pelayanan apa adanya :fire::fire:'

df.loc[
    (df['commenter_username'] == 'indra_wahyudi_suroboyo') &
    (df['comment_text'] == 'Sebaiknya kalau ada giat pekerjaan mematikan aliran Air PDAM kepada Warga. Beberapa hari sebelumnya ada pemberitahuan agar warga dapat mempersiapkan dampaknya. Kebraon mati dari tadi jam 7.30 sampai pukul 13.10 juga belum mengalir.Padahal PDAM bisa lebih profesional dalam pelayanan kepada masyarakat. Bukan hanya maaf saja. Agar tidak menjadi Budaya pelayanan apa adanya :fire::fire:'),
    ['true_aspect_1']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'indra_wahyudi_suroboyo') &
    (df['comment_text'] == 'Sebaiknya kalau ada giat pekerjaan mematikan aliran Air PDAM kepada Warga. Beberapa hari sebelumnya ada pemberitahuan agar warga dapat mempersiapkan dampaknya. Kebraon mati dari tadi jam 7.30 sampai pukul 13.10 juga belum mengalir.Padahal PDAM bisa lebih profesional dalam pelayanan kepada masyarakat. Bukan hanya maaf saja. Agar tidak menjadi Budaya pelayanan apa adanya :fire::fire:'),
    ['true_aspect_2']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'octasilvia') &
    (df['comment_text'] == 'Mbok ngasih pengumuman dulu baru dimatikan min, ini malah sebaliknya bolak balik komplain tp gak diperhatikan sarannya customer, padahal kan klo ada acara perbaikan itu ada planningnya gak grusak grusuk'),
    ['comment_text']
] = 'Mbok ngasih pengumuman dulu baru dimatikan min, ini malah sebaliknya bolak balik komplain tp gak diperhatikan sarannya customer, kan klo ada acara perbaikan itu ada planningnya gak grusak grusuk'

df.loc[
    (df['commenter_username'] == 'becak_rodadua') &
    (df['comment_text'] == 'airnya mati sampai kpn ya? kenapa pemadaman air nya di saat orang sedang mau aktivitas? area terdampak nya kedurus ini mati'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'garnetha.sheehan') &
    (df['comment_text'] == 'Kalo matikan air itu ada pemberitahuan dong,biar org juga persiapan. Area kedurus mati, gimana sihhh'),
    ['comment_text']
] = 'Kalo matikan air itu ada pemberitahuan dong,biar org juga persiapan. Karena area kedurus mati, gimana sihhh'

df.loc[
    (df['commenter_username'] == 'garnetha.sheehan') &
    (df['comment_text'] == 'Kalo matikan air itu ada pemberitahuan dong,biar org juga persiapan. Karena area kedurus mati, gimana sihhh'),
    ['true_aspect_2']
] = 'Air Tidak Mengalir'

df.loc[
    (df['commenter_username'] == 'garnetha.sheehan') &
    (df['comment_text'] == 'Kalo matikan air itu ada pemberitahuan dong,biar org juga persiapan. Karena area kedurus mati, gimana sihhh'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'ynn_joyo') &
    (df['comment_text'] == 'Pengajuan selalu diundur2 kayabundur2 dari 2024 sampai sekarang blm jelas kendala apanjuga ndak ada info sampai apk cis sdh dihapus'),
    ['comment_text']
] = 'Pengajuan selalu diundur2 kayabundur2 dari 2024 tapi sampai sekarang blm jelas kendala apanjuga ndak ada info sampai apk cis sdh dihapus'

df.loc[
    (df['commenter_username'] == 'lucky.sastrosadarpo') &
    (df['comment_text'] == 'Mohon maaf, bisa tolong dibantu untuk menindaklanjuti laporan saya tentang air keruh di daerah Ngagel Jaya Selatan. Tgl 26 Februari saya sudah lapor via WA dan tgl 4 Maret saya lapor lagi via WA. Mohon jadi perhatian ya untuk kualitas air, karena kamu gunakan untuk kebutuhan sehari-hari. Terima kasih :clapping_hands_light_skin_tone:'),
    ['true_aspect_2']
] = 'Air Kotor/Bau'

df.loc[
    (df['commenter_username'] == 'tukangmaiido') &
    (df['comment_text'] == 'Emang kalau mau pasang baru kena biaya berapa min'),
    ['comment_text']
] = 'Emang kalau mau pasang baru akan kena biaya berapa min'

df.loc[
    (df['commenter_username'] == 'akudanalam05') &
    (df['comment_text'] == 'kmrn depan rumah pdam bocor iseng ke pengaduan di aplikasi saya kira bakal datang 3 harian.. lho gak taunya langsung gercep.. hari itu juga datang.. good job..'),
    ['true_aspect_2']
] = 'Kebocoran'

df.loc[
    (df['commenter_username'] == 'putri_indah_031') &
    (df['comment_text'] == 'Kemarin sudah diganti, setahun uda 2x .. bapak" yang catat meteran gercep .. tau mati langsung laporan yang punya rumah, bahwa meteran matii .. gak kayak PLN, meteran mati sudah bertahun" ( saya kontrak baru 1 tahun ).. jadi tiap bulan ak bayar cuma abonemen aja, mana tau saya kalau meterran rusak .. ehh ndilalah kmrn yang catat meteran ganti orang, langsung d report kalau meteran matiii .. dan alhasil saya membayar tagihan 6 bulan ke belakang.. total 1,2 jutaa ..'),
    ['true_aspect_2']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'amaliaamalia207') &
    (df['comment_text'] == 'benar gratis ya min, soalnya dulu saya pernah tanya klau ganti meteran air ada biaya'),
    ['comment_text']
] = 'benar gratis ya min, karena dulu saya pernah tanya klau ganti meteran air ada biaya'

df.loc[
    (df['commenter_username'] == 'evisponsaria') &
    (df['comment_text'] == 'Punya saya meteran mati, sudah TTD di aplikasi petugas sampai skrg gak ada lanjutan min'),
    ['comment_text']
] = 'Punya saya meteran mati, sudah TTD di aplikasi tapi petugas sampai skrg gak ada lanjutan min'

df.loc[
    (df['commenter_username'] == 'salmasalma_25') &
    (df['comment_text'] == 'Pak,,klu mau meninggikan meteran bayar nggak ya? Soalnya letaknya ada dibawah sekali dan sangat menyusahkan petugas klu mau cek meteran'),
    ['comment_text']
] = 'Pak, klu mau meninggikan meteran bayar nggak ya? Karena letaknya ada dibawah sekali dan sangat menyusahkan petugas klu mau cek meteran'

df.loc[
    (df['commenter_username'] == 'salmasalma_25') &
    (df['comment_text'] == 'Pak, klu mau meninggikan meteran bayar nggak ya? Karena letaknya ada dibawah sekali dan sangat menyusahkan petugas klu mau cek meteran'),
    ['true_aspect_2']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == 'salmasalma_25') &
    (df['comment_text'] == 'Pak, klu mau meninggikan meteran bayar nggak ya? Karena letaknya ada dibawah sekali dan sangat menyusahkan petugas klu mau cek meteran'),
    ['true_aspect_1']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'mossibudi') &
    (df['comment_text'] == 'Byk yg protes kl stlh diganti meteran maka tagihannya sdh naik tajam padahal org nya ya sama persis bertahun2, bener ya?'),
    ['true_aspect_1']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'prast79') &
    (df['comment_text'] == 'Wes sebulan lebih cuma di inspeksi saja dan belum ada tindakan lanjut(meteran air buram dan ndak muter)'),
    ['comment_text']
] = 'Wes sebulan lebih cuma di inspeksi saja dan belum ada tindakan lanjut. Karena meteran air buram dan ndak muter)'

df.loc[
    (df['commenter_username'] == 'prast79') &
    (df['comment_text'] == 'Wes sebulan lebih cuma di inspeksi saja dan belum ada tindakan lanjut. Karena meteran air buram dan ndak muter)'),
    ['true_aspect_1']
] = 'Pelayanan'

df.loc[
    (df['commenter_username'] == 'prast79') &
    (df['comment_text'] == 'Wes sebulan lebih cuma di inspeksi saja dan belum ada tindakan lanjut. Karena meteran air buram dan ndak muter)'),
    ['true_aspect_2']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == 'dsatyarini81') &
    (df['comment_text'] == 'Saya kapan hari lapor kena biaya pergantian meteran'),
    ['true_aspect_2']
] = 'Harga'

df.loc[
    (df['commenter_username'] == 'namakuriva') &
    (df['comment_text'] == 'Lapor meteran buram, cuma dilihat,dicatat trus belum ada tindakan lanjutan'),
    ['comment_text']
] = 'Lapor meteran buram, tapi cuma dilihat,dicatat trus belum ada tindakan lanjutan'

df.loc[
    (df['commenter_username'] == 'vickysamsudin') &
    (df['comment_text'] == 'Permisi admin mau tanya.. Hari ini ada petugas pdam yg datang dan bilang kalau ada program dri pdam untuk meteran yang sudah 5 tahun akan di ganti baru secara gratis, apa itu benar ya min?'),
    ['comment_text']
] = 'Permisi admin mau tanya.. Hari ini ada petugas pdam yg datang dan bilang kalau ada program dri pdam untuk meteran yang sudah 5 tahun di ganti baru tapi gratis, apa itu benar ya min?'

df.loc[
    (df['commenter_username'] == 'vickysamsudin') &
    (df['comment_text'] == 'Permisi admin mau tanya.. Hari ini ada petugas pdam yg datang dan bilang kalau ada program dri pdam untuk meteran yang sudah 5 tahun di ganti baru tapi gratis, apa itu benar ya min?'),
    ['true_aspect_1']
] = 'Meteran (Macet/Bermasalah)'

df.loc[
    (df['commenter_username'] == 'miftachul_retna') &
    (df['comment_text'] == 'Sudah 2minggu lebih air didaerah jambangan mengicil. Sudah lapor bolak balik belum ada petugas yg datang buat mengecek.'),
    ['comment_text']
] = 'Sudah 2minggu lebih air didaerah jambangan mengicil. Sudah lapor bolak balik tapi belum ada petugas yg datang buat mengecek.'

df.loc[
    (df['commenter_username'] == 'miethachun') &
    (df['comment_text'] == 'Daerah tegalsari air PDAM ga layak pakai seperti air sungai sudah 2hr ini,sekarang mati'),
    ['comment_text']
] = 'Daerah tegalsari air PDAM ga layak pakai seperti air sungai sudah 2hr ini,tapi sekarang airnya mati'

df.loc[
    (df['commenter_username'] == 'arytristianto') &
    (df['comment_text'] == 'Stop kran pdam saya rusak usia sudah 5 tahun lebih, meteran pdam muter terus tanpa dipakai rugi saya. Saya wa pdam sby untuk perbaikan stop kran saya di kenakan biaya Rp 197.580,- Apa iya bayar? :clapping_hands:'),
    ['true_aspect_2']
] = 'Meteran (Macet/Bermasalah)'

# Simpan ulang CSV bersih
df.to_csv(
    "data_with_true_label_fixed.csv",
    index=False,
    encoding='utf-8-sig'
)
